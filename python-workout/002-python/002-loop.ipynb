# %%
i = 1
while i < 6:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# countdown with while loop:
number = 5

while number > 0:
    print(number)
    number -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
number = 1

while number < 5:
    print(number)
    number += 1
# Out:
# 1
# 2
# 3
# 4

# %%
number = 0

while number < 10:
    if number % 2 == 0:
        print(number)
    
    number += 1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
number = 0

while number < 10:
    if number % 2 != 0:
        print(number)
    
    number += 1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# count
number = 0

while number < 3:
    print(number)
    number += 1
# Out:
# 0
# 1
# 2

# %%
# reverse count
number = 3

while number > 0:
    print(number)
    number -= 1
# Out:
# 3
# 2
# 1

# %%
# even
number = 0

while number < 10:
    if number % 2 == 0:
        print(number)
    number += 1
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
number = 0

while number < 10:
    if number % 2 != 0:
        print(number)
    number += 1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
number = 1
total = 0

while number <= 5:
    total += number
    number += 1

print(total)

# %%
number = 1
total = 0

while number <= 10:
    total += number
    number += 1

print(total)
# Out:
# 55

# %%
i = 1

while i <= 5:
    print(i)
    i += 1

print("done")
# Out:
# 1
# 2
# 3
# 4
# 5
# done

# %%
i = 1

while i <= 5:
    print('*' * i)
    i += 1

print("done")
# Out:
# *
# **
# ***
# ****
# *****
# done

# %%
i = 2

while i <= 10:
    print(i)
    i += 2
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
secret_num = 9
guess_count = 0
guess_limit = 3

while guess_count < guess_limit:
    guess = int(input("gesuu: "))

    guess_count += 1
    if guess == secret_num:
        print("u win !")
